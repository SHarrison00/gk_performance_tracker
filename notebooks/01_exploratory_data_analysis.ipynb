# %% [markdown]
# ## Load Packages & Set Paths

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import duckdb

REPO_ROOT = Path().resolve().parents[0]
DB_PATH = REPO_ROOT / "dbt_project" / "dev.duckdb"
print(REPO_ROOT)
print(DB_PATH)
# Out:
# /Users/samharrison/Documents/data_sci/gk_performance_tracker/gk_performance_tracker
# /Users/samharrison/Documents/data_sci/gk_performance_tracker/gk_performance_tracker/dbt_project/dev.duckdb

# %% [markdown]
# ## Connect to `duckdb` DB & Create Query-Function

# %%
# Connect to duckdb
con = duckdb.connect(str(DB_PATH), read_only=False)
con.execute("PRAGMA enable_progress_bar=true;")

# Create query-function
def q(sql: str, *params):
    """Run a SQL query and return a pandas DataFrame."""
    return con.execute(sql, params).df()

pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)

# Example usage of query-function
q("""
select *
from stg_matchlogs__parsed
where minutes_played > 0
and competition = 'Premier League' 
limit 100
""")
# Out:
#                    source_table         goalkeeper     season  match_date  \
# 0      aaron_ramsdale_2025_2026     aaron_ramsdale  2025_2026  2025-11-09
# 1      aaron_ramsdale_2025_2026     aaron_ramsdale  2025_2026  2025-11-29
# 2      aaron_ramsdale_2025_2026     aaron_ramsdale  2025_2026  2025-12-02
# 3      aaron_ramsdale_2025_2026     aaron_ramsdale  2025_2026  2025-12-06
# 4      aaron_ramsdale_2025_2026     aaron_ramsdale  2025_2026  2025-12-14
# ..                          ...                ...        ...         ...
# 95  caoimhin_kelleher_2025_2026  caoimhin_kelleher  2025_2026  2025-12-27
# 96         david_raya_2025_2026         david_raya  2025_2026  2025-08-17
# 97         david_raya_2025_2026         david_raya  2025_2026  2025-08-23
# 98         david_raya_2025_2026         david_raya  2025_2026  2025-08-31
# 99         david_raya_2025_2026         david_raya  2025_2026  2025-09-13
#
#        competition         round venue result           team         opponent  \
# 0   Premier League  Matchweek 11  Away  L 1–3  Newcastle Utd        Brentford
# 1   Premier League  Matchweek 13  Away  W 4–1  Newcastle Utd          Everton
# 2   Premier League  Matchweek 14  Home  D 2–2  Newcastle Utd        Tottenham
# 3   Premier League  Matchweek 15  Home  W 2–1  Newcastle Utd          Burnley
# 4   Premier League  Matchweek 16  Away  L 0–1  Newcastle Utd       Sunderland
# ..             ...           ...   ...    ...            ...              ...
# 95  Premier League  Matchweek 18  Home  W 4–1      Brentford      Bournemouth
# 96  Premier League   Matchweek 1  Away  W 1–0        Arsenal   Manchester Utd
# 97  Premier League   Matchweek 2  Home  W 5–0        Arsenal     Leeds United
# 98  Premier League   Matchweek 3  Away  L 0–1        Arsenal        Liverpool
# 99  Premier League   Matchweek 4  Home  W 3–0        Arsenal  Nott'ham Forest
#
#    game_started  minutes_played  gk_shots_on_target_against  gk_goals_against  \
# 0             N              14                         3.0               2.0
# 1             Y              90                         2.0               1.0
# 2             Y              90                         2.0               2.0
# 3             Y              90                         3.0               1.0
# 4             Y              90                         1.0               1.0
# ..          ...             ...                         ...               ...
# 95            Y              90                         9.0               1.0
# 96            Y              90                         7.0               0.0
# 97            Y              90                         1.0               0.0
# 98            Y              90                         3.0               1.0
# 99            Y              90                         1.0               0.0
#
#     gk_saves  gk_clean_sheets  gk_psxg  gk_pens_att  gk_pens_allowed  \
# 0        1.0              0.0      1.4          1.0              1.0
# 1        1.0              0.0      0.9          0.0              0.0
# 2        0.0              0.0      1.4          0.0              0.0
# 3        2.0              0.0      1.2          1.0              1.0
# 4        1.0              0.0      0.2          0.0              0.0
# ..       ...              ...      ...          ...              ...
# 95       8.0              0.0      1.2          0.0              0.0
# 96       7.0              1.0      0.7          0.0              0.0
# 97       1.0              1.0      0.1          0.0              0.0
# 98       2.0              0.0      0.3          0.0              0.0
# 99       1.0              1.0      0.1          0.0              0.0
#
#     gk_pens_saved  gk_pens_missed  gk_passes_launched  \
# 0             0.0             0.0                 2.0
# 1             0.0             0.0                15.0
# 2             0.0             0.0                 8.0
# 3             0.0             0.0                 4.0
# 4             0.0             0.0                14.0
# ..            ...             ...                 ...
# 95            0.0             0.0                22.0
# 96            0.0             0.0                20.0
# 97            0.0             0.0                 7.0
# 98            0.0             0.0                26.0
# 99            0.0             0.0                 6.0
#
#     gk_passes_completed_launched  gk_passes  gk_passes_throws  \
# 0                            0.0        3.0               0.0
# 1                            5.0       31.0               5.0
# 2                            1.0       24.0               3.0
# 3                            1.0       32.0               8.0
# 4                            6.0       36.0               7.0
# ..                           ...        ...               ...
# 95                          10.0       39.0               5.0
# 96                           5.0       28.0               9.0
# 97                           4.0       32.0               1.0
# 98                          12.0       49.0               7.0
# 99                           3.0       32.0               5.0
#
#     gk_passes_length_avg  gk_goal_kicks  gk_goal_kicks_launched  \
# 0                   37.0            3.0                   0.999
# 1                   32.6            5.0                   4.000
# 2                   29.3            3.0                   3.000
# 3                   26.1            5.0                   1.000
# 4                   31.7            7.0                   3.997
# ..                   ...            ...                     ...
# 95                  37.6            3.0                   3.000
# 96                  34.4            9.0                   9.000
# 97                  28.8            0.0                     NaN
# 98                  40.3            2.0                   2.000
# 99                  26.1            1.0                   0.000
#
#     gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# 0                      39.3         6.0                 0.0
# 1                      62.4        18.0                 1.0
# 2                      62.3        24.0                 1.0
# 3                      31.2        14.0                 1.0
# 4                      51.3        12.0                 1.0
# ..                      ...         ...                 ...
# 95                     61.3        30.0                 0.0
# 96                     64.8        11.0                 2.0
# 97                      NaN         3.0                 1.0
# 98                     69.0         6.0                 2.0
# 99                     21.0         9.0                 0.0
#
#     gk_def_actions_outside_pen_area  gk_avg_distance_def_actions
# 0                               0.0                          NaN
# 1                               0.0                          4.0
# 2                               0.0                          5.3
# 3                               5.0                         17.9
# 4                               2.0                         19.2
# ..                              ...                          ...
# 95                              0.0                         11.0
# 96                              0.0                          9.2
# 97                              0.0                          3.5
# 98                              2.0                         17.6
# 99                              2.0                         23.3
#
# [100 rows x 33 columns]

# %% [markdown]
# ## Data Marts

# %% [markdown]
# ### a) Goalkeeper Performance Summary Table: `fct_goalkeeper_performance`

# %%
# Summarise goalkeeper performacnce
q("""
select *
from fct_goalkeeper_performance
""")
# Out:
#               goalkeeper             team          goalkeeper_1  \
# 0             david_raya          Arsenal            david_raya
# 1        jordan_pickford          Everton       jordan_pickford
# 2         robert_sanchez          Chelsea        robert_sanchez
# 3       djordje_petrovic      Bournemouth      djordje_petrovic
# 4        bart_verbruggen         Brighton       bart_verbruggen
# 5        martin_dubravka          Burnley       martin_dubravka
# 6         dean_henderson   Crystal Palace        dean_henderson
# 7            robin_roefs       Sunderland           robin_roefs
# 8      guglielmo_vicario        Tottenham     guglielmo_vicario
# 9             bernd_leno           Fulham            bernd_leno
# 10     caoimhin_kelleher        Brentford     caoimhin_kelleher
# 11  gianluigi_donnarumma  Manchester City  gianluigi_donnarumma
# 12     emiliano_martinez      Aston Villa     emiliano_martinez
# 13             matz_sels  Nott'ham Forest             matz_sels
# 14       alphonse_areola         West Ham       alphonse_areola
# 15             nick_pope    Newcastle Utd             nick_pope
# 16               alisson        Liverpool               alisson
# 17           lucas_perri     Leeds United           lucas_perri
# 18         senne_lammens   Manchester Utd         senne_lammens
# 19         sam_johnstone           Wolves         sam_johnstone
# 20        aaron_ramsdale    Newcastle Utd        aaron_ramsdale
# 21               jose_sa           Wolves               jose_sa
# 22        altay_bayindir   Manchester Utd        altay_bayindir
# 23  giorgi_mamardashvili        Liverpool  giorgi_mamardashvili
# 24           karl_darlow     Leeds United           karl_darlow
# 25                  john  Nott'ham Forest                  john
# 26           marco_bizot      Aston Villa           marco_bizot
# 27        mads_hermansen         West Ham        mads_hermansen
# 28        james_trafford  Manchester City        james_trafford
# 29       filip_jorgensen          Chelsea       filip_jorgensen
#
#     matches_played  clean_sheets    ga  saves  shots_on_target_against  \
# 0               19           9.0  12.0   31.0                     43.0
# 1               19           8.0  20.0   50.0                     71.0
# 2               19           8.0  19.0   44.0                     63.0
# 3               19           5.0  35.0   53.0                     87.0
# 4               19           4.0  27.0   54.0                     79.0
# 5               19           3.0  37.0   67.0                    101.0
# 6               18           7.0  20.0   44.0                     64.0
# 7               18           6.0  18.0   61.0                     79.0
# 8               18           6.0  23.0   51.0                     74.0
# 9               18           5.0  26.0   48.0                     72.0
# 10              18           3.0  26.0   49.0                     75.0
# 11              15           7.0  13.0   27.0                     41.0
# 12              15           4.0  15.0   42.0                     58.0
# 13              15           2.0  25.0   47.0                     71.0
# 14              15           0.0  27.0   55.0                     81.0
# 15              13           5.0  14.0   41.0                     54.0
# 16              13           4.0  16.0   26.0                     42.0
# 17              13           2.0  24.0   29.0                     53.0
# 18              13           2.0  18.0   31.0                     49.0
# 19              12           0.0  24.0   39.0                     59.0
# 20               7           0.0  10.0   10.0                     19.0
# 21               7           0.0  16.0   16.0                     32.0
# 22               6           0.0  11.0   13.0                     24.0
# 23               5           1.0  10.0   16.0                     27.0
# 24               5           0.0   8.0   13.0                     20.0
# 25               4           1.0   5.0    5.0                     10.0
# 26               4           1.0   8.0    9.0                     16.0
# 27               4           1.0  11.0    9.0                     20.0
# 28               3           1.0   4.0   11.0                     15.0
# 29               1           0.0   2.0    1.0                      3.0
#
#     save_pct  psxg_minus_ga  crosses_faced_p90  crosses_stopped_pct  \
# 0       72.1           -1.1                9.8                 11.3
# 1       70.4            2.8               16.2                  3.2
# 2       69.8            1.2               12.9                 13.8
# 3       60.9           -5.1               14.0                  8.3
# 4       68.4            0.0               14.0                  4.6
# 5       66.3            0.1               20.1                  3.5
# 6       68.8            1.9               16.4                  4.5
# 7       77.2            2.1               19.8                 10.3
# 8       68.9            1.1               15.4                  4.8
# 9       66.7           -4.3               15.0                  5.3
# 10      65.3           -3.0               17.3                  4.3
# 11      65.9            0.8               13.1                  4.0
# 12      72.4            1.2               16.9                 11.0
# 13      66.2           -1.5               15.1                  4.4
# 14      67.9           -2.1               19.8                  4.5
# 15      75.9           -0.4               13.3                 14.3
# 16      61.9           -1.4               14.4                  6.0
# 17      54.7           -2.9               14.7                  4.1
# 18      63.3            1.3               19.1                  4.9
# 19      66.1           -5.5               19.7                  4.7
# 20      52.6           -2.6               16.4                  6.6
# 21      50.0           -5.0               15.6                  5.1
# 22      54.2           -1.6               11.7                  9.5
# 23      59.3           -2.5               13.3                  3.3
# 24      65.0           -2.9               18.2                  6.1
# 25      50.0           -1.4               10.0                  0.0
# 26      56.3           -2.1               15.0                 11.1
# 27      45.0           -1.8               20.0                  6.9
# 28      73.3            1.9                9.6                  7.7
# 29      33.3           -0.2               23.8                  0.0
#
#     pass_att_p90  long_kick_pass_completion_pct  \
# 0           35.7                           33.2
# 1           38.9                           36.8
# 2           42.9                           30.0
# 3           25.6                           31.1
# 4           45.4                           25.0
# 5           29.5                           31.9
# 6           31.1                           24.3
# 7           40.7                           24.8
# 8           39.0                           29.8
# 9           39.1                           25.1
# 10          36.2                           36.8
# 11          26.7                           35.9
# 12          42.2                           37.1
# 13          26.1                           29.5
# 14          25.3                           29.1
# 15          25.0                           24.7
# 16          37.4                           32.1
# 17          39.9                           24.3
# 18          31.3                           29.6
# 19          36.6                           37.9
# 20          33.0                           27.9
# 21          29.4                           36.1
# 22          32.6                           29.5
# 23          39.1                           32.2
# 24          40.2                           30.0
# 25          25.6                           39.7
# 26          38.6                           31.1
# 27          39.2                           26.4
# 28          38.1                           27.8
# 29          36.9                           30.0
#
#     def_actions_outside_pen_area_p90  avg_distance_def_actions
# 0                                2.0                 21.511429
# 1                                2.1                 18.200000
# 2                                1.3                 17.176190
# 3                                1.9                 16.418750
# 4                                1.4                 16.845833
# 5                                0.8                 12.446154
# 6                                0.7                 15.390909
# 7                                1.4                 17.963636
# 8                                2.1                 18.923529
# 9                                0.6                 17.070000
# 10                               1.4                 17.347826
# 11                               0.4                 14.416667
# 12                               0.7                 18.370000
# 13                               1.3                 19.688235
# 14                               0.1                 31.000000
# 15                               3.1                 18.647222
# 16                               1.3                 16.020000
# 17                               0.3                 16.300000
# 18                               0.9                 22.381818
# 19                               1.9                 18.080952
# 20                               1.6                 17.388889
# 21                               1.0                 17.433333
# 22                               1.3                 17.957143
# 23                               2.0                 18.744444
# 24                               0.9                 13.475000
# 25                               1.1                 22.550000
# 26                               3.1                 19.245455
# 27                               0.3                 10.400000
# 28                               5.2                 20.035714
# 29                               1.2                 16.300000

# %% [markdown]
# ### b) Goalkeeper Relative Performance vs. League: `mart_goalkeeper_league_ratings`

# %% [markdown]
# Comment re. validation from the Fozcast Top-10

# %%
q("""
select *
from mart_goalkeeper_league_ratings
""")
# Out:
#               goalkeeper             team  save_pct  psxg_minus_ga  \
# 0              nick_pope    Newcastle Utd      75.9           -0.4
# 1         robert_sanchez          Chelsea      69.8            1.2
# 2            robin_roefs       Sunderland      77.2            2.1
# 3      emiliano_martinez      Aston Villa      72.4            1.2
# 4        jordan_pickford          Everton      70.4            2.8
# 5             david_raya          Arsenal      72.1           -1.1
# 6      guglielmo_vicario        Tottenham      68.9            1.1
# 7        bart_verbruggen         Brighton      68.4            0.0
# 8         dean_henderson   Crystal Palace      68.8            1.9
# 9          senne_lammens   Manchester Utd      63.3            1.3
# 10               alisson        Liverpool      61.9           -1.4
# 11  gianluigi_donnarumma  Manchester City      65.9            0.8
# 12     caoimhin_kelleher        Brentford      65.3           -3.0
# 13       martin_dubravka          Burnley      66.3            0.1
# 14         sam_johnstone           Wolves      66.1           -5.5
# 15           karl_darlow     Leeds United      65.0           -2.9
# 16        altay_bayindir   Manchester Utd      54.2           -1.6
# 17  giorgi_mamardashvili        Liverpool      59.3           -2.5
# 18             matz_sels  Nott'ham Forest      66.2           -1.5
# 19      djordje_petrovic      Bournemouth      60.9           -5.1
# 20        aaron_ramsdale    Newcastle Utd      52.6           -2.6
# 21            bernd_leno           Fulham      66.7           -4.3
# 22       alphonse_areola         West Ham      67.9           -2.1
# 23           lucas_perri     Leeds United      54.7           -2.9
# 24               jose_sa           Wolves      50.0           -5.0
#
#     crosses_stopped_pct  pass_att_p90  long_kick_pass_completion_pct  \
# 0                  14.3          25.0                           24.7
# 1                  13.8          42.9                           30.0
# 2                  10.3          40.7                           24.8
# 3                  11.0          42.2                           37.1
# 4                   3.2          38.9                           36.8
# 5                  11.3          35.7                           33.2
# 6                   4.8          39.0                           29.8
# 7                   4.6          45.4                           25.0
# 8                   4.5          31.1                           24.3
# 9                   4.9          31.3                           29.6
# 10                  6.0          37.4                           32.1
# 11                  4.0          26.7                           35.9
# 12                  4.3          36.2                           36.8
# 13                  3.5          29.5                           31.9
# 14                  4.7          36.6                           37.9
# 15                  6.1          40.2                           30.0
# 16                  9.5          32.6                           29.5
# 17                  3.3          39.1                           32.2
# 18                  4.4          26.1                           29.5
# 19                  8.3          25.6                           31.1
# 20                  6.6          33.0                           27.9
# 21                  5.3          39.1                           25.1
# 22                  4.5          25.3                           29.1
# 23                  4.1          39.9                           24.3
# 24                  5.1          29.4                           36.1
#
#     def_actions_outside_pen_area_p90  z_save_pct  z_psxg_minus_ga  \
# 0                                3.1    1.579903         0.329280
# 1                                1.3    0.678537         1.008209
# 2                                1.4    1.771997         1.390106
# 3                                0.7    1.062725         1.008209
# 4                                2.1    0.767195         1.687137
# 5                                2.0    1.018396         0.032249
# 6                                2.1    0.545548         0.965776
# 7                                1.4    0.471666         0.499012
# 8                                0.7    0.530772         1.305240
# 9                                0.9   -0.281935         1.050642
# 10                               1.3   -0.488806        -0.095050
# 11                               0.4    0.102253         0.838476
# 12                               1.4    0.013594        -0.773978
# 13                               0.8    0.161359         0.541445
# 14                               1.9    0.131806        -1.834804
# 15                               0.9   -0.030735        -0.731545
# 16                               1.3   -1.626596        -0.179916
# 17                               2.0   -0.872995        -0.561813
# 18                               1.3    0.146583        -0.137483
# 19                               1.9   -0.636571        -1.665072
# 20                               1.6   -1.863020        -0.604246
# 21                               0.6    0.220465        -1.325608
# 22                               0.1    0.397783        -0.392081
# 23                               0.3   -1.552714        -0.731545
# 24                               1.0   -2.247209        -1.622639
#
#     z_crosses_stopped_pct  z_pass_att_p90  z_long_kick_pass_completion_pct  \
# 0                2.421737       -1.616720                        -1.360826
# 1                2.266577        1.349587                        -0.135898
# 2                1.180457        0.985013                        -1.337714
# 3                1.397681        1.233586                         1.505044
# 4               -1.022814        0.686725                         1.435709
# 5                1.490777        0.156435                         0.603682
# 6               -0.526303        0.703296                        -0.182121
# 7               -0.588367        1.763875                        -1.291491
# 8               -0.619399       -0.605856                        -1.453274
# 9               -0.495271       -0.572713                        -0.228345
# 10              -0.153919        0.438152                         0.349451
# 11              -0.774558       -1.335004                         1.227702
# 12              -0.681463        0.239293                         1.435709
# 13              -0.929718       -0.871000                         0.303228
# 14              -0.557335        0.305579                         1.689939
# 15              -0.122887        0.902155                        -0.135898
# 16               0.932201       -0.357283                        -0.251457
# 17              -0.991782        0.719868                         0.372563
# 18              -0.650431       -1.434433                        -0.251457
# 19               0.559817       -1.517291                         0.118333
# 20               0.032273       -0.290996                        -0.621247
# 21              -0.371143        0.719868                        -1.268379
# 22              -0.619399       -1.567005                        -0.343904
# 23              -0.743526        0.852440                        -1.453274
# 24              -0.433207       -0.887572                         1.273926
#
#     z_def_actions_outside_pen_area_p90  pct_save_pct  pct_psxg_minus_ga  \
# 0                             2.658583     95.833333          58.333333
# 1                             0.000000     79.166667          79.166667
# 2                             0.147699    100.000000          95.833333
# 3                            -0.886194     91.666667          79.166667
# 4                             1.181592     83.333333         100.000000
# 5                             1.033893     87.500000          54.166667
# 6                             1.181592     75.000000          75.000000
# 7                             0.147699     66.666667          62.500000
# 8                            -0.886194     70.833333          91.666667
# 9                            -0.590796     29.166667          87.500000
# 10                            0.000000     25.000000          50.000000
# 11                           -1.329291     41.666667          70.833333
# 12                            0.147699     37.500000          16.666667
# 13                           -0.738495     54.166667          66.666667
# 14                            0.886194     45.833333           0.000000
# 15                           -0.590796     33.333333          20.833333
# 16                            0.000000      8.333333          41.666667
# 17                            1.033893     16.666667          33.333333
# 18                            0.000000     50.000000          45.833333
# 19                            0.886194     20.833333           4.166667
# 20                            0.443097      4.166667          29.166667
# 21                           -1.033893     58.333333          12.500000
# 22                           -1.772389     62.500000          37.500000
# 23                           -1.476990     12.500000          20.833333
# 24                           -0.443097      0.000000           8.333333
#
#     pct_crosses_stopped_pct  pct_pass_att_p90  \
# 0                100.000000          0.000000
# 1                 95.833333         95.833333
# 2                 83.333333         87.500000
# 3                 87.500000         91.666667
# 4                  0.000000         62.500000
# 5                 91.666667         45.833333
# 6                 45.833333         66.666667
# 7                 37.500000        100.000000
# 8                 29.166667         29.166667
# 9                 50.000000         33.333333
# 10                62.500000         58.333333
# 11                12.500000         16.666667
# 12                20.833333         50.000000
# 13                 8.333333         25.000000
# 14                41.666667         54.166667
# 15                66.666667         83.333333
# 16                79.166667         37.500000
# 17                 4.166667         70.833333
# 18                25.000000         12.500000
# 19                75.000000          8.333333
# 20                70.833333         41.666667
# 21                58.333333         70.833333
# 22                29.166667          4.166667
# 23                16.666667         79.166667
# 24                54.166667         20.833333
#
#     pct_long_kick_pass_completion_pct  pct_def_actions_outside_pen_area_p90  \
# 0                            8.333333                            100.000000
# 1                           50.000000                             41.666667
# 2                           12.500000                             58.333333
# 3                           95.833333                             16.666667
# 4                           87.500000                             91.666667
# 5                           75.000000                             83.333333
# 6                           45.833333                             91.666667
# 7                           16.666667                             58.333333
# 8                            0.000000                             16.666667
# 9                           41.666667                             29.166667
# 10                          66.666667                             41.666667
# 11                          79.166667                              8.333333
# 12                          87.500000                             58.333333
# 13                          62.500000                             25.000000
# 14                         100.000000                             75.000000
# 15                          50.000000                             29.166667
# 16                          33.333333                             41.666667
# 17                          70.833333                             83.333333
# 18                          33.333333                             41.666667
# 19                          58.333333                             75.000000
# 20                          25.000000                             70.833333
# 21                          20.833333                             12.500000
# 22                          29.166667                              0.000000
# 23                           0.000000                              4.166667
# 24                          83.333333                             37.500000
#
#     overall_score  overall_rank
# 0        0.983681             1
# 1        0.962444             2
# 2        0.924902             3
# 3        0.885067             4
# 4        0.760143             5
# 5        0.740993             6
# 6        0.474649             7
# 7        0.170806             8
# 8       -0.030258             9
# 9       -0.061506            10
# 10      -0.073547            11
# 11      -0.134966            12
# 12      -0.137413            13
# 13      -0.185862            14
# 14      -0.211326            15
# 15      -0.225604            16
# 16      -0.244732            17
# 17      -0.249082            18
# 18      -0.303729            19
# 19      -0.438585            20
# 20      -0.541971            21
# 21      -0.571472            22
# 22      -0.599293            23
# 23      -0.923766            24
# 24      -0.969572            25

# %% [markdown]
# ## Radar Chart: Example

# %%
import numpy as np
import pandas as pd
import plotly.graph_objects as go

METRIC_CONFIG = {
    "save_pct": ("Save %", "{:.1f}%"),
    "psxg_minus_ga": ("PSxG - GA", "{:.1f}"),
    "crosses_stopped_pct": ("Cross Stop %", "{:.1f}%"),
    "pass_att_p90": ("Passes Att. (per 90)", ""),
    "long_kick_pass_completion_pct": ("Long Pass Completion %", "{:.1f}%"),
    "def_actions_outside_pen_area_p90": ("Def. Actions OPA (per 90)", "{:.1f}"),
}

METRIC_COLS = list(METRIC_CONFIG)
METRIC_LABELS = {c: METRIC_CONFIG[c][0] for c in METRIC_COLS}
THETA = list(METRIC_LABELS.values())


def get_goalkeeper_data(goalkeeper: str, df: pd.DataFrame) -> tuple[pd.Series, pd.Series, pd.Series]:
    gk_row = df.loc[df["goalkeeper"] == goalkeeper].squeeze()

    raw_values = pd.Series({
        METRIC_LABELS[c]: METRIC_CONFIG[c][1].format(gk_row[c]) if METRIC_CONFIG[c][1] else gk_row[c]
        for c in METRIC_COLS
    })

    z_scores = gk_row[[f"z_{c}" for c in METRIC_COLS]].rename({f"z_{c}": METRIC_LABELS[c] for c in METRIC_COLS})
    percentiles = gk_row[[f"pct_{c}" for c in METRIC_COLS]].rename({f"pct_{c}": METRIC_LABELS[c] for c in METRIC_COLS})

    return raw_values, z_scores, percentiles


def plot_goalkeeper_radar(goalkeepers: str | list[str], df: pd.DataFrame) -> go.Figure:
    fig = go.Figure()
    max_z_score = 0

    for gk in goalkeepers:
        raw_values, z_scores, percentiles = get_goalkeeper_data(gk, df)
        max_z_score = max(abs(z_scores).max(), max_z_score)

        customdata = np.column_stack([
            raw_values.reindex(THETA).to_numpy(),
            percentiles.reindex(THETA).to_numpy(),
        ])

        fig.add_trace(
            go.Scatterpolar(
                r = z_scores.reindex(THETA).to_numpy(),
                theta = THETA,
                fill = "toself",
                name = gk.replace("_", " ").title(),
                customdata = customdata,
                hovertemplate = (
                    "<b>%{theta}</b><br>"
                    "Value: %{customdata[0]}<br>"
                    "Percentile: %{customdata[1]:.0f}th<br>"
                    "Z-score: %{r:.2f}<br>"
                    "<extra></extra>"
                ),
            )
        )

    fig.update_layout(
        polar = dict(radialaxis = dict(visible = True, range = list((-1 * max_z_score, max_z_score)))),
        showlegend = True,
        title = "Goalkeeper Performance",
        width=700,
        height=700
    )
    return fig


# Example usage
df = q("select * from mart_goalkeeper_league_ratings")
fig = plot_goalkeeper_radar(["nick_pope", "alisson", "jose_sa"], df)
fig.show()
